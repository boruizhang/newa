# %% [markdown]
# 3 Labels I O B (Verbs)

# %%
pip install NERDA
# Out:
# Collecting NERDA
#   Downloading NERDA-1.0.0-py3-none-any.whl (23 kB)
# Collecting transformers
#   Downloading transformers-4.12.3-py3-none-any.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 7.6 MB/s
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from NERDA) (3.2.5)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from NERDA) (1.9.0+cu111)
# Collecting pyconll
#   Downloading pyconll-3.1.0-py3-none-any.whl (26 kB)
# Collecting progressbar
#   Downloading progressbar-2.5.tar.gz (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from NERDA) (1.1.5)
# Requirement already satisfied: sklearn in /usr/local/lib/python3.7/dist-packages (from NERDA) (0.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nltk->NERDA) (1.15.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->NERDA) (2.8.2)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.7/dist-packages (from pandas->NERDA) (1.19.5)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->NERDA) (2018.9)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from sklearn->NERDA) (0.22.2.post1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sklearn->NERDA) (1.0.1)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sklearn->NERDA) (1.4.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch->NERDA) (3.7.4.3)
# Collecting sacremoses
#   Downloading sacremoses-0.0.46-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 37.0 MB/s
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading tokenizers-0.10.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 23.3 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers->NERDA) (2.23.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers->NERDA) (21.0)
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.1.0-py3-none-any.whl (59 kB)
#      |████████████████████████████████| 59 kB 5.7 MB/s
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 42.4 MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers->NERDA) (3.3.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers->NERDA) (4.62.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers->NERDA) (2019.12.20)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers->NERDA) (4.8.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers->NERDA) (2.4.7)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers->NERDA) (3.6.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers->NERDA) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers->NERDA) (2021.5.30)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers->NERDA) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers->NERDA) (2.10)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers->NERDA) (7.1.2)
# Building wheels for collected packages: progressbar
#   Building wheel for progressbar (setup.py) ... done
#   Created wheel for progressbar: filename=progressbar-2.5-py3-none-any.whl size=12082 sha256=1dc6602a676b81b663f228883f9de382b5df2a4838d9431ce9a6517ce7932eec
#   Stored in directory: /root/.cache/pip/wheels/f0/fd/1f/3e35ed57e94cd8ced38dd46771f1f0f94f65fec548659ed855
# Successfully built progressbar
# Installing collected packages: pyyaml, tokenizers, sacremoses, huggingface-hub, transformers, pyconll, progressbar, NERDA
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed NERDA-1.0.0 huggingface-hub-0.1.0 progressbar-2.5 pyconll-3.1.0 pyyaml-6.0 sacremoses-0.0.46 tokenizers-0.10.3 transformers-4.12.3

# %%
from collections import defaultdict
import itertools
# import WhitespaceTokenizer() method from nltk
from nltk.tokenize import WhitespaceTokenizer
# Create a reference variable for Class WhitespaceTokenizer
tk = WhitespaceTokenizer()

d = defaultdict(list)
d['sentences'] = []
d['tags'] = []
t = defaultdict(list)
t['sentences'] = []
t['tags'] = []
test = defaultdict(list)
test['sentences'] = []
test['tags'] = []

# %%
def nerda_format(data):
  ner = defaultdict(list)
  for line1,line2 in itertools.zip_longest(*[data]*2):
    sents = []
    tags = []
    tokens = iter(tk.tokenize(line1))
    verbs = tk.tokenize(line2)
    for token in tokens:
      if token == "[":
        pass
      elif token == "]":
        pass
      elif token not in verbs:
        tags.append("O")
        sents.append(token)
      elif token == verbs[0]:
        tags.append("B")
        sents.append(token)
      elif token in verbs and verbs[verbs.index(token)-1] == ",":
        tags.append("B")
        sents.append(token)
      elif token in verbs and token != verbs[0]:
        tags.append("I")
        sents.append(token)
    ner['sentences'].append(sents)
    ner['tags'].append(tags)
  return ner

# %%
with open('dev.txt') as data:
    d = nerda_format(data)
    #d['sentences'] = ner['sentences']
    #d['tags'] = ner['tags']

with open('train.txt') as data:
    t = nerda_format(data)
  #  t['sentences'] = ner['sentences']
  #  t['tags'] = ner['tags']

with open('test.txt') as data:
    test = nerda_format(data)
  #  test['sentences'] = ner['sentences']
  #  test['tags'] = ner['tags']

#print(len(d['sentences']))
#print (d['sentences'][1])
#print (d['tags'][1])

# %%
d_total_O = 0
t_total_O = 0
test_total_O = 0

d_total_I = 0
t_total_I = 0
test_total_I = 0

d_total_B = 0
t_total_B = 0
test_total_B = 0

d_total_BV = 0
t_total_BV = 0
test_total_BV = 0

d_total_OV = 0
t_total_OV = 0
test_total_OV = 0

d_total_IV = 0
t_total_IV = 0
test_total_IV = 0


for elem in d['tags']:
  d_total_O += elem.count('O')
  d_total_I += elem.count('I')
  d_total_B += elem.count('B')
  d_total_IV += elem.count('I-V')
  d_total_BV += elem.count('B-V')
  d_total_OV += elem.count('O-V')

for elem in t['tags']:
  t_total_O += elem.count('O')
  t_total_I += elem.count('I')
  t_total_B += elem.count('B')
  t_total_IV += elem.count('I-V')
  t_total_BV += elem.count('B-V')
  t_total_OV += elem.count('O-V')

for elem in test['tags']:
  test_total_O += elem.count('O')
  test_total_I += elem.count('I')
  test_total_B += elem.count('B')
  test_total_IV += elem.count('I-V')
  test_total_BV += elem.count('B-V')
  test_total_OV += elem.count('O-V')

# %%
print ('I' + '=' + str(d_total_I + t_total_I + test_total_I))
print ('O' + '=' + str(d_total_O + t_total_O + test_total_O))
print ('B' + '=' + str(d_total_B + t_total_B + test_total_B))
print ('IV' + '=' + str(d_total_IV + t_total_IV + test_total_IV))
print ('OV' + '=' + str(d_total_OV + t_total_OV + test_total_OV))
print ('BV' + '=' + str(d_total_BV + t_total_BV + test_total_BV))
# Out:
# I=63
# O=4334
# B=76
# IV=0
# OV=0
# BV=0

# %%
import NERDA
training = t
validation = d

# %%
print(training.get('sentences')[0])
# Out:
# ['थः', 'नं', 'छम्ह', 'शक्तिशाली', 'खः', 'धयागु', 'आत्मविश्वास', 'ज्वनाः', 'न्ह्याःवःगु', 'खनेदु']

# %%
tag_scheme = [
'I',
'B'
]

# %%
from NERDA.models import NERDA
model = NERDA(
dataset_training = training,
dataset_validation = validation,
tag_scheme = tag_scheme, 
tag_outside = 'O',
transformer = 'bert-base-multilingual-cased',
hyperparameters = {'epochs' : 11,
                  'warmup_steps' : 10,
                  'train_batch_size': 7,
                  'learning_rate': 0.0001})
# Out:
# Device automatically set to: cuda
# Downloading:   0%|          | 0.00/625 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/681M [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-base-multilingual-cased were not used when initializing BertModel: ['cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.bias', 'cls.predictions.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Downloading:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/972k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.87M [00:00<?, ?B/s]

# %%
model.train()
# Out:
#  Epoch 1 / 11
#   0%|          | 0/22 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #6 length 261 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
# /usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #14 length 152 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
#  18%|█▊        | 4/22 [00:01<00:08,  2.24it/s]/usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #48 length 150 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
#  23%|██▎       | 5/22 [00:02<00:07,  2.28it/s]/usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #49 length 130 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
# /usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #50 length 174 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
# /usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #53 length 233 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
# /usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #54 length 149 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
#  32%|███▏      | 7/22 [00:03<00:06,  2.31it/s]/usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #68 length 132 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
#  41%|████      | 9/22 [00:03<00:05,  2.34it/s]/usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #77 length 171 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
#  45%|████▌     | 10/22 [00:04<00:05,  2.34it/s]/usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #87 length 128 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
#  59%|█████▉    | 13/22 [00:05<00:03,  2.36it/s]/usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #107 length 127 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
# 100%|██████████| 22/22 [00:09<00:00,  2.31it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #6 length 327 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
# /usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #16 length 132 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
# 100%|██████████| 6/6 [00:00<00:00,  7.06it/s]
# Train Loss = 0.14758741593157704 Valid Loss = 0.10861294344067574
#
#  Epoch 2 / 11
#   0%|          | 0/22 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #6 length 261 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
# /usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #14 length 152 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
#  18%|█▊        | 4/22 [00:01<00:07,  2.29it/s]/usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #48 length 150 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
#  23%|██▎       | 5/22 [00:02<00:07,  2.33it/s]/usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #49 length 130 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
# /usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #50 length 174 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
# /usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #53 length 233 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
# /usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #54 length 149 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
#  32%|███▏      | 7/22 [00:03<00:06,  2.34it/s]/usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #68 length 132 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
#  41%|████      | 9/22 [00:03<00:05,  2.37it/s]/usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #77 length 171 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
#  45%|████▌     | 10/22 [00:04<00:05,  2.37it/s]/usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #87 length 128 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
#  59%|█████▉    | 13/22 [00:05<00:03,  2.35it/s]/usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #107 length 127 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
# 100%|██████████| 22/22 [00:09<00:00,  2.33it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #6 length 327 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
# /usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #16 length 132 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
# 100%|██████████| 6/6 [00:00<00:00,  6.94it/s]
# Train Loss = 0.14170747868378053 Valid Loss = 0.12870060466229916
#
#  Epoch 3 / 11
#   0%|          | 0/22 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #6 length 261 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
# /usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #14 length 152 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
#  18%|█▊        | 4/22 [00:01<00:07,  2.30it/s]/usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #48 length 150 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
#  23%|██▎       | 5/22 [00:02<00:07,  2.33it/s]/usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #49 length 130 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
# /usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #50 length 174 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
# /usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #53 length 233 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
# /usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #54 length 149 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
#  32%|███▏      | 7/22 [00:03<00:06,  2.35it/s]/usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #68 length 132 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
#  41%|████      | 9/22 [00:03<00:05,  2.35it/s]/usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #77 length 171 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
#  45%|████▌     | 10/22 [00:04<00:05,  2.36it/s]/usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #87 length 128 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
#  59%|█████▉    | 13/22 [00:05<00:03,  2.36it/s]/usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #107 length 127 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
# 100%|██████████| 22/22 [00:09<00:00,  2.33it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #6 length 327 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
# /usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #16 length 132 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
# 100%|██████████| 6/6 [00:00<00:00,  6.97it/s]
# Train Loss = 0.13501391729170625 Valid Loss = 0.11947381061812241
#
#  Epoch 4 / 11
#   0%|          | 0/22 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #6 length 261 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
# /usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #14 length 152 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
#  18%|█▊        | 4/22 [00:01<00:07,  2.30it/s]/usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #48 length 150 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
#  23%|██▎       | 5/22 [00:02<00:07,  2.31it/s]/usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #49 length 130 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
# /usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #50 length 174 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
# /usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #53 length 233 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
# /usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #54 length 149 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
#  32%|███▏      | 7/22 [00:03<00:06,  2.35it/s]/usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #68 length 132 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
#  41%|████      | 9/22 [00:03<00:05,  2.36it/s]/usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #77 length 171 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
#  45%|████▌     | 10/22 [00:04<00:05,  2.36it/s]/usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #87 length 128 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
#  59%|█████▉    | 13/22 [00:05<00:03,  2.36it/s]/usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #107 length 127 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
# 100%|██████████| 22/22 [00:09<00:00,  2.33it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #6 length 327 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
# /usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #16 length 132 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
# 100%|██████████| 6/6 [00:00<00:00,  7.07it/s]
# Train Loss = 0.12419194245541637 Valid Loss = 0.09580252412706614
#
#  Epoch 5 / 11
#   0%|          | 0/22 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #6 length 261 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
# /usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #14 length 152 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
#  18%|█▊        | 4/22 [00:01<00:07,  2.31it/s]/usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #48 length 150 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
#  23%|██▎       | 5/22 [00:02<00:07,  2.34it/s]/usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #49 length 130 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
# /usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #50 length 174 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
# /usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #53 length 233 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
# /usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #54 length 149 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
#  32%|███▏      | 7/22 [00:03<00:06,  2.35it/s]/usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #68 length 132 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
#  41%|████      | 9/22 [00:03<00:05,  2.38it/s]/usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #77 length 171 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
#  45%|████▌     | 10/22 [00:04<00:05,  2.36it/s]/usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #87 length 128 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
#  59%|█████▉    | 13/22 [00:05<00:03,  2.37it/s]/usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #107 length 127 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
# 100%|██████████| 22/22 [00:09<00:00,  2.34it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #6 length 327 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
# /usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #16 length 132 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
# 100%|██████████| 6/6 [00:00<00:00,  7.28it/s]
# Train Loss = 0.11138478429480032 Valid Loss = 0.12208559736609459
#
#  Epoch 6 / 11
#   0%|          | 0/22 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #6 length 261 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
# /usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #14 length 152 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
#  18%|█▊        | 4/22 [00:01<00:07,  2.28it/s]/usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #48 length 150 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
#  23%|██▎       | 5/22 [00:02<00:07,  2.31it/s]/usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #49 length 130 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
# /usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #50 length 174 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
# /usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #53 length 233 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
# /usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #54 length 149 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
#  32%|███▏      | 7/22 [00:03<00:06,  2.33it/s]/usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #68 length 132 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
#  41%|████      | 9/22 [00:03<00:05,  2.34it/s]/usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #77 length 171 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
#  45%|████▌     | 10/22 [00:04<00:05,  2.36it/s]/usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #87 length 128 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
#  59%|█████▉    | 13/22 [00:05<00:03,  2.36it/s]/usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #107 length 127 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
# 100%|██████████| 22/22 [00:09<00:00,  2.33it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #6 length 327 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
# /usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #16 length 132 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
# 100%|██████████| 6/6 [00:00<00:00,  7.14it/s]
# Train Loss = 0.08325287767431953 Valid Loss = 0.1328353563634058
#
#  Epoch 7 / 11
#   0%|          | 0/22 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #6 length 261 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
# /usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #14 length 152 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
#  18%|█▊        | 4/22 [00:01<00:07,  2.31it/s]/usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #48 length 150 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
#  23%|██▎       | 5/22 [00:02<00:07,  2.34it/s]/usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #49 length 130 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
# /usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #50 length 174 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
# /usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #53 length 233 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
# /usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #54 length 149 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
#  32%|███▏      | 7/22 [00:03<00:06,  2.35it/s]/usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #68 length 132 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
#  41%|████      | 9/22 [00:03<00:05,  2.35it/s]/usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #77 length 171 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
#  45%|████▌     | 10/22 [00:04<00:05,  2.36it/s]/usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #87 length 128 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
#  59%|█████▉    | 13/22 [00:05<00:03,  2.37it/s]/usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #107 length 127 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
# 100%|██████████| 22/22 [00:09<00:00,  2.34it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #6 length 327 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
# /usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #16 length 132 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
# 100%|██████████| 6/6 [00:00<00:00,  6.93it/s]
# Train Loss = 0.08080232778394764 Valid Loss = 0.12351614500706394
#
#  Epoch 8 / 11
#   0%|          | 0/22 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #6 length 261 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
# /usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #14 length 152 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
#  18%|█▊        | 4/22 [00:01<00:07,  2.30it/s]/usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #48 length 150 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
#  23%|██▎       | 5/22 [00:02<00:07,  2.34it/s]/usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #49 length 130 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
# /usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #50 length 174 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
# /usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #53 length 233 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
# /usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #54 length 149 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
#  32%|███▏      | 7/22 [00:03<00:06,  2.37it/s]/usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #68 length 132 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
#  41%|████      | 9/22 [00:03<00:05,  2.36it/s]/usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #77 length 171 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
#  45%|████▌     | 10/22 [00:04<00:05,  2.36it/s]/usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #87 length 128 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
#  59%|█████▉    | 13/22 [00:05<00:03,  2.38it/s]/usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #107 length 127 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
# 100%|██████████| 22/22 [00:09<00:00,  2.34it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #6 length 327 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
# /usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #16 length 132 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
# 100%|██████████| 6/6 [00:00<00:00,  6.84it/s]
# Train Loss = 0.10229670425707643 Valid Loss = 0.12296633251632254
#
#  Epoch 9 / 11
#   0%|          | 0/22 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #6 length 261 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
# /usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #14 length 152 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
#  18%|█▊        | 4/22 [00:01<00:07,  2.33it/s]/usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #48 length 150 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
#  23%|██▎       | 5/22 [00:02<00:07,  2.33it/s]/usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #49 length 130 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
# /usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #50 length 174 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
# /usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #53 length 233 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
# /usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #54 length 149 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
#  32%|███▏      | 7/22 [00:03<00:06,  2.34it/s]/usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #68 length 132 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
#  41%|████      | 9/22 [00:03<00:05,  2.35it/s]/usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #77 length 171 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
#  45%|████▌     | 10/22 [00:04<00:05,  2.36it/s]/usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #87 length 128 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
#  59%|█████▉    | 13/22 [00:05<00:03,  2.35it/s]/usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #107 length 127 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
# 100%|██████████| 22/22 [00:09<00:00,  2.34it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #6 length 327 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
# /usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #16 length 132 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
# 100%|██████████| 6/6 [00:00<00:00,  7.03it/s]
# Train Loss = 0.07618535254997286 Valid Loss = 0.13099154147009054
#
#  Epoch 10 / 11
#   0%|          | 0/22 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #6 length 261 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
# /usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #14 length 152 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
#  18%|█▊        | 4/22 [00:01<00:07,  2.32it/s]/usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #48 length 150 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
#  23%|██▎       | 5/22 [00:02<00:07,  2.35it/s]/usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #49 length 130 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
# /usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #50 length 174 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
# /usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #53 length 233 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
# /usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #54 length 149 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
#  32%|███▏      | 7/22 [00:03<00:06,  2.36it/s]/usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #68 length 132 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
#  41%|████      | 9/22 [00:03<00:05,  2.36it/s]/usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #77 length 171 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
#  45%|████▌     | 10/22 [00:04<00:05,  2.38it/s]/usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #87 length 128 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
#  59%|█████▉    | 13/22 [00:05<00:03,  2.38it/s]/usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #107 length 127 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
# 100%|██████████| 22/22 [00:09<00:00,  2.34it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #6 length 327 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
# /usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #16 length 132 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
# 100%|██████████| 6/6 [00:00<00:00,  7.14it/s]
# Train Loss = 0.04416435125114566 Valid Loss = 0.15565372755130133
#
#  Epoch 11 / 11
#   0%|          | 0/22 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #6 length 261 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
# /usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #14 length 152 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
#  18%|█▊        | 4/22 [00:01<00:07,  2.31it/s]/usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #48 length 150 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
#  23%|██▎       | 5/22 [00:02<00:07,  2.32it/s]/usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #49 length 130 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
# /usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #50 length 174 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
# /usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #53 length 233 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
# /usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #54 length 149 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
#  32%|███▏      | 7/22 [00:03<00:06,  2.37it/s]/usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #68 length 132 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
#  41%|████      | 9/22 [00:03<00:05,  2.37it/s]/usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #77 length 171 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
#  45%|████▌     | 10/22 [00:04<00:05,  2.38it/s]/usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #87 length 128 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
#  59%|█████▉    | 13/22 [00:05<00:03,  2.37it/s]/usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #107 length 127 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
# 100%|██████████| 22/22 [00:09<00:00,  2.34it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #6 length 327 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
# /usr/local/lib/python3.7/dist-packages/NERDA/preprocessing.py:80: UserWarning: Sentence #16 length 132 exceeds max_len 128 and has been truncated
#   warnings.warn(msg)
# 100%|██████████| 6/6 [00:00<00:00,  7.13it/s]
# Train Loss = 0.03743014534385028 Valid Loss = 0.16327083731691042
# 'Model trained successfully'

# %%
model.evaluate_performance(test)
# Out:
#        Level  F1-Score  Precision    Recall
# 0          I  0.285714   0.333333  0.250000
# 1          B  0.666667   0.666667  0.666667
# 0  AVG_MICRO  0.461538        NaN       NaN
# 0  AVG_MICRO  0.476190        NaN       NaN

# %%
#text= [['अझ', 'वृहद', 'कथं', 'धायेगु', 'खःसा', 'थ्व', 'विज्ञान', 'ब्रह्माण्ड', 'गथे', 'सनाच्वंगु', 'दु', 'धका', 'स्वयेत','याइगु', 'प्रकृतिया', 'साधारण', 'एनालाइसिस', 'ख']]
print(model.predict([test['sentences'][1]]))
print(test['tags'][1])
# Out:
# [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']]
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I', 'I', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I', 'I', 'O']

# %%
## Getting the confusion matrices for every test sentence

from sklearn.metrics import confusion_matrix
y_true = test['tags']
for n in range (len(test['tags'])):
  y_pred = []
  y_pred = model.predict([test['sentences'][n]])[0]
  #print(y_true[n])
  #print(y_pred)
  print(confusion_matrix(y_true[n], y_pred, labels=["I", "O", 'B']))
# Out:
# [[ 0  0  0]
#  [ 0 26  0]
#  [ 0  0  0]]
# [[ 1  3  0]
#  [ 0 19  0]
#  [ 0  0  0]]
# [[ 0  0  0]
#  [ 0 11  0]
#  [ 0  0  0]]
# [[ 0  0  0]
#  [ 0 22  0]
#  [ 0  0  0]]
# [[ 0  0  0]
#  [ 0 30  0]
#  [ 0  1  0]]
# [[ 0  0  0]
#  [ 0 11  0]
#  [ 0  0  0]]
# [[ 0  0  0]
#  [ 0 15  0]
#  [ 0  0  1]]
# [[ 0  0  0]
#  [ 0 13  0]
#  [ 0  0  0]]
# [[ 0  0  0]
#  [ 1 19  0]
#  [ 0  0  1]]
# [[ 0  0  0]
#  [ 0 12  0]
#  [ 0  0  0]]
# [[ 0  0  0]
#  [ 0 17  1]
#  [ 0  0  0]]
# [[ 0  0  0]
#  [ 0 23  0]
#  [ 0  0  0]]
# [[ 0  0  0]
#  [ 1 14  0]
#  [ 0  0  0]]

# %%
# Sum up the 6by6 confusion matrix result in every test sentence
import numpy as np
from sklearn.metrics import confusion_matrix
y_true = test['tags']
d = np.zeros((3,3))
for n in range (len(test['tags'])):
  y_pred = []
  y_pred = model.predict([test['sentences'][n]])[0]
  #print(y_true[n])
  #print(y_pred)
  d += confusion_matrix(y_true[n], y_pred, labels=["I", "O","B"])
print(d)
# Out:
# [[  1.   3.   0.]
#  [  2. 232.   1.]
#  [  0.   1.   2.]]
